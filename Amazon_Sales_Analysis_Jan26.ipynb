# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreeya555/AIML-Basics_Advanced/blob/main/Amazon_Sales_Analysis_Jan26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/179/351/original/data.csv?1770634820
# Out:
# --2026-02-11 16:05:58--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/179/351/original/data.csv?1770634820
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 3.165.84.173, 3.165.84.59, 3.165.84.114, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|3.165.84.173|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5926734 (5.7M) [text/plain]
# Saving to: ‘data.csv?1770634820’
#
# data.csv?1770634820 100%[===================>]   5.65M  --.-KB/s    in 0.02s
#
# 2026-02-11 16:05:58 (256 MB/s) - ‘data.csv?1770634820’ saved [5926734/5926734]

# %%
import pandas as pd
df = pd.read_csv("/content/data.csv?1770634820")

# %%
df
# Out:
#       product_id                                            user_id  \
# 0     B0912WJ87V  AG6W5HESRSDLBX3NCYOOUGFOWERA,AED4U5CF37HVSYPMD...
# 1     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 2     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 3     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 4     B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# ...          ...                                                ...
# 1719  B00S2SEV7K  AFSJUWV2I4CD53EPCRMOQJ3CWR3Q,AGLYAYWTFPPMLELDG...
# 1720  B086Q3QMFS  AENWPLS2BHDMH4O6DD7EYV5DOGHQ,AGWEZX7ZMZNEDPVTP...
# 1721  B07LFQLKFZ  AG23N2Z5CVKFJZ6ZLIYU4NQTDKFA,AG2T5VLGSYCC4K6VI...
# 1722  B00LY17RHI  AE6FSULFZEB65U7FWSETNHLBP5JQ,AGV3YW3GZJTWUP4FC...
# 1723  B00DJ5N9VK  AE5D3EMPETKIA4VU4SZU5UIHXKQA,AFF76KWKCMR6GNPUX...
#
#                                               user_name  \
# 0     Arivazhagan,Ajit,swanand pandit,Venkatesh S.,S...
# ...

# %%
products= df[['product_id', 'product_name', 'category', 'discounted_price', 'actual_price','calculated_discount']].drop_duplicates()

# %%
products
# Out:
#       product_id                                       product_name  \
# 0     B0912WJ87V  Reffair AX30 [MAX] Portable Air Purifier for C...
# 1     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 4     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 7     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 8     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# ...          ...                                                ...
# 1719  B00S2SEV7K  Pilot Frixion Clicker Roller Pen (Blue), (9000...
# 1720  B086Q3QMFS  Classmate Drawing Book - Unruled, 40 Pages, 21...
# 1721  B07LFQLKFZ  Parker Moments Vector Timecheck Gold Trim Roll...
# 1722  B00LY17RHI      Camlin Elegante Fountain Pen - Black/Blue/Red
# 1723  B00DJ5N9VK  Faber-Castell Connector Pen Set - Pack of 25 (...
#
#                    category  discounted_price  actual_price  \
# 0             Car&Motorbike            2339.0        4000.0
# ...

# %%
#PANDAS MELT


new_products= pd.melt(products,
        id_vars= ['product_id', 'product_name', 'category'],
        value_vars=['discounted_price', 'actual_price','calculated_discount'],
        var_name='col',
        value_name='value')

# %%
products[products['product_id']=='B0912WJ87V']
# Out:
#    product_id                                       product_name  \
# 0  B0912WJ87V  Reffair AX30 [MAX] Portable Air Purifier for C...
#
#         category  discounted_price  actual_price  calculated_discount
# 0  Car&Motorbike            2339.0        4000.0               41.525

# %%
new_products[new_products['product_id']=='B0912WJ87V']
# Out:
#       product_id                                       product_name  \
# 0     B0912WJ87V  Reffair AX30 [MAX] Portable Air Purifier for C...
# 1349  B0912WJ87V  Reffair AX30 [MAX] Portable Air Purifier for C...
# 2698  B0912WJ87V  Reffair AX30 [MAX] Portable Air Purifier for C...
#
#            category                  col     value
# 0     Car&Motorbike     discounted_price  2339.000
# 1349  Car&Motorbike         actual_price  4000.000
# 2698  Car&Motorbike  calculated_discount    41.525

# %%
new_products
# Out:
#       product_id                                       product_name  \
# 0     B0912WJ87V  Reffair AX30 [MAX] Portable Air Purifier for C...
# 1     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 3     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 4     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# ...          ...                                                ...
# 4042  B00S2SEV7K  Pilot Frixion Clicker Roller Pen (Blue), (9000...
# 4043  B086Q3QMFS  Classmate Drawing Book - Unruled, 40 Pages, 21...
# 4044  B07LFQLKFZ  Parker Moments Vector Timecheck Gold Trim Roll...
# 4045  B00LY17RHI      Camlin Elegante Fountain Pen - Black/Blue/Red
# 4046  B00DJ5N9VK  Faber-Castell Connector Pen Set - Pack of 25 (...
#
#                    category                  col   value
# 0             Car&Motorbike     discounted_price  2339.0
# ...

# %%
products_reversal= pd.pivot_table(new_products,
               index=['product_id', 'product_name', 'category'],
               columns= 'col',
               values= 'value')

# %%
products_reversal.reset_index()
# Out:
# col   product_id                                       product_name  \
# 0     B002PD61Y4  D-Link DWA-131 300 Mbps Wireless Nano USB Adap...
# 1     B002SZEOLG  TP-Link Nano USB WiFi Dongle 150Mbps High Gain...
# 2     B003B00484  Duracell Plus AAA Rechargeable Batteries (750 ...
# 3     B003L62T7W  Logitech B100 Wired USB Mouse, 3 yr Warranty, ...
# 4     B004IO5BMQ  Logitech M235 Wireless Mouse, 1000 DPI Optical...
# ...          ...                                                ...
# 1339  B0BPBXNQQT  Room Heater Warmer Wall-Outlet 400 Watts Elect...
# 1340  B0BPCJM7TB  WIDEWINGS Electric Handheld Milk Wand Mixer Fr...
# 1341  B0BQ3K23Y1  Oratech Coffee Frother electric, milk frother ...
# 1342  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# 1343  B0BR4F878Q  Swiffer Instant Electric Water Heater Faucet T...
#
# col                category  actual_price  calculated_discount  \
# 0     Computers&Accessories        1208.0            58.029801
# ...

# %%
df.head()
# Out:
#    product_id                                            user_id  \
# 0  B0912WJ87V  AG6W5HESRSDLBX3NCYOOUGFOWERA,AED4U5CF37HVSYPMD...
# 1  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 2  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 3  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 4  B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
#
#                                            user_name  \
# 0  Arivazhagan,Ajit,swanand pandit,Venkatesh S.,S...
# 1  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 2  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 3  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 4  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
#
#                                            review_id  \
# 0  R3TOOFPX256D59,R1PR50BDQOEIIO,R392FI4QWXWOX5,R...
# 1  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# ...

# %%
df[df['review_content'].str.contains('durable')]
# Out:
#       product_id                                            user_id  \
# 1     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 2     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 3     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 7     B096MSW6CT  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 8     B096MSW6CT  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# ...          ...                                                ...
# 1546  B09SDDQQKP  AE4L3MBEACOHT7Y7GGWQ72DUJ6SA,AELHNY42N2WPTZN5R...
# 1586  B09R1YFL6S  AHAXZDBQKLBWPQN5BFPSURNHWECA,AEGH2WM5MITQZBEZM...
# 1640  B09HS1NDRQ  AGW2ESCSKYPOEDCQW2H3CYYA3QBQ,AFWNPTLGMCGHXXZKY...
# 1658  B089BDBDGM  AEBNUYHIR7GVMMLJXH5ONPDIJF7Q,AGPI7NG4ZSTCPPICR...
# 1691  B07JF9B592  AHQ4Q75NBEWOM4OWOXUZW7V247NQ,AEQCAMSZJTMNIKXAP...
#
#                                               user_name  \
# 1     Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1724 entries, 0 to 1723
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  1724 non-null   object
#  1   user_id                     1724 non-null   object
#  2   user_name                   1724 non-null   object
#  3   review_id                   1724 non-null   object
#  4   review_title                1724 non-null   object
#  5   review_content              1724 non-null   object
#  6   order_timestamp             1724 non-null   object
#  7   product_name                1724 non-null   object
#  8   category                    1724 non-null   object
#  9   discounted_price            1711 non-null   float64
#  10  actual_price                1716 non-null   float64
#  11  rating                      1704 non-null   float64
#  12  rating_count                1722 non-null   float64
# ...

# %%
df['order_timestamp_new']=pd.to_datetime(df['order_timestamp'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1724 entries, 0 to 1723
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  1724 non-null   object
#  1   user_id                     1724 non-null   object
#  2   user_name                   1724 non-null   object
#  3   review_id                   1724 non-null   object
#  4   review_title                1724 non-null   object
#  5   review_content              1724 non-null   object
#  6   order_timestamp             1724 non-null   object
#  7   product_name                1724 non-null   object
#  8   category                    1724 non-null   object
#  9   discounted_price            1711 non-null   float64
#  10  actual_price                1716 non-null   float64
#  11  rating                      1704 non-null   float64
#  12  rating_count                1722 non-null   float64
# ...

# %%
df['year']=df['order_timestamp_new'].dt.year
df['month']=df['order_timestamp_new'].dt.month
df['week_number']=df['order_timestamp_new'].dt.isocalendar().week
df['week_name']=df['order_timestamp_new'].dt.day_name()

# %%
df
# Out:
#       product_id                                            user_id  \
# 0     B0912WJ87V  AG6W5HESRSDLBX3NCYOOUGFOWERA,AED4U5CF37HVSYPMD...
# 1     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 2     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 3     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 4     B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# ...          ...                                                ...
# 1719  B00S2SEV7K  AFSJUWV2I4CD53EPCRMOQJ3CWR3Q,AGLYAYWTFPPMLELDG...
# 1720  B086Q3QMFS  AENWPLS2BHDMH4O6DD7EYV5DOGHQ,AGWEZX7ZMZNEDPVTP...
# 1721  B07LFQLKFZ  AG23N2Z5CVKFJZ6ZLIYU4NQTDKFA,AG2T5VLGSYCC4K6VI...
# 1722  B00LY17RHI  AE6FSULFZEB65U7FWSETNHLBP5JQ,AGV3YW3GZJTWUP4FC...
# 1723  B00DJ5N9VK  AE5D3EMPETKIA4VU4SZU5UIHXKQA,AFF76KWKCMR6GNPUX...
#
#                                               user_name  \
# 0     Arivazhagan,Ajit,swanand pandit,Venkatesh S.,S...
# ...

# %%
df['required_format'] = df['order_timestamp_new'].dt.strftime('%B %d, %Y')

# %%
df
# Out:
#       product_id                                            user_id  \
# 0     B0912WJ87V  AG6W5HESRSDLBX3NCYOOUGFOWERA,AED4U5CF37HVSYPMD...
# 1     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 2     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 3     B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 4     B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# ...          ...                                                ...
# 1719  B00S2SEV7K  AFSJUWV2I4CD53EPCRMOQJ3CWR3Q,AGLYAYWTFPPMLELDG...
# 1720  B086Q3QMFS  AENWPLS2BHDMH4O6DD7EYV5DOGHQ,AGWEZX7ZMZNEDPVTP...
# 1721  B07LFQLKFZ  AG23N2Z5CVKFJZ6ZLIYU4NQTDKFA,AG2T5VLGSYCC4K6VI...
# 1722  B00LY17RHI  AE6FSULFZEB65U7FWSETNHLBP5JQ,AGV3YW3GZJTWUP4FC...
# 1723  B00DJ5N9VK  AE5D3EMPETKIA4VU4SZU5UIHXKQA,AFF76KWKCMR6GNPUX...
#
#                                               user_name  \
# 0     Arivazhagan,Ajit,swanand pandit,Venkatesh S.,S...
# ...

# %%
df['rating']
# Out:
# 0       3.8
# 1       4.2
# 2       4.2
# 3       4.2
# 4       4.0
#        ...
# 1719    4.1
# 1720    4.5
# 1721    4.2
# 1722    4.1
# 1723    4.3
# Name: rating, Length: 1724, dtype: float64

# %%
df['rating'].mean()
# Out:
# np.float64(4.108509389671362)

# %%
#how is this spread across

import seaborn as sns

sns.histplot(df['rating'])
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
import matplotlib.pyplot as plt

# %%
plt.title("Rating Distribution")
sns.histplot(df['rating'])
plt.xlabel("Ratings")
plt.ylabel("Frequency")

plt.show()

# %%
#Identify popular product categories

sns.countplot(data=df, x='category')
plt.xticks(rotation=90)
plt.show()

# %%
#discounted price and ratings


sns.scatterplot(x='discounted_price', y='rating', data =df)
# Out:
# <Axes: xlabel='discounted_price', ylabel='rating'>

# %%
sns.scatterplot(x='discounted_price', y='actual_price', data =df)
# Out:
# <Axes: xlabel='discounted_price', ylabel='actual_price'>

# %%
sns.scatterplot(x='discounted_price', y='actual_price', hue='category', data =df)
# Out:
# <Axes: xlabel='discounted_price', ylabel='actual_price'>

# %%
sns.scatterplot(x='discounted_price', y='rating', hue='category', data =df)
# Out:
# <Axes: xlabel='discounted_price', ylabel='rating'>

# %%
df.head()
# Out:
#    product_id                                            user_id  \
# 0  B0912WJ87V  AG6W5HESRSDLBX3NCYOOUGFOWERA,AED4U5CF37HVSYPMD...
# 1  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 2  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 3  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 4  B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
#
#                                            user_name  \
# 0  Arivazhagan,Ajit,swanand pandit,Venkatesh S.,S...
# 1  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 2  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 3  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 4  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
#
#                                            review_id  \
# 0  R3TOOFPX256D59,R1PR50BDQOEIIO,R392FI4QWXWOX5,R...
# 1  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# ...

# %%
df['discount_range']= pd.cut(df['discounted_price'],
       bins=[0.0,50.0,399.0,1000.0],
       labels=['low_discount','mid-discount','high', ]
       )

# %%
df.head()
# Out:
#    product_id                                            user_id  \
# 0  B0912WJ87V  AG6W5HESRSDLBX3NCYOOUGFOWERA,AED4U5CF37HVSYPMD...
# 1  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 2  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 3  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 4  B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
#
#                                            user_name  \
# 0  Arivazhagan,Ajit,swanand pandit,Venkatesh S.,S...
# 1  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 2  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 3  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 4  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
#
#                                            review_id  \
# 0  R3TOOFPX256D59,R1PR50BDQOEIIO,R392FI4QWXWOX5,R...
# 1  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# ...

# %%
sns.countplot(x='discount_range', data =df)
# Out:
# <Axes: xlabel='discount_range', ylabel='count'>

# %%
sns.boxplot(y='discounted_price', data=df)
# Out:
# <Axes: ylabel='discounted_price'>

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(x='category', y='rating', data=df, palette='Set3')

plt.xticks(rotation=90)

plt.show()
# Out:
# /tmp/ipython-input-754201738.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='category', y='rating', data=df, palette='Set3')

# %%
cf= df[['actual_price','discounted_price', 'rating']].corr()

# %%
cf
# Out:
#                   actual_price  discounted_price    rating
# actual_price          1.000000          0.961293  0.107635
# discounted_price      0.961293          1.000000  0.102599
# rating                0.107635          0.102599  1.000000

# %%
sns.heatmap(cf, annot=True) #mutltivariate analysis
# Out:
# <Axes: >

# %%
sns.heatmap(df[['rating', 'discounted_price', 'actual_price', 'calculated_discount_filled']].corr(), annot=True)
# Out:
# <Axes: >

# %%
dg= df[['rating', 'discounted_price', 'actual_price', 'calculated_discount_filled']]

# %%
sns.pairplot(dg)

# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/397/original/Sachin_ODI.csv
# Out:
# --2026-02-11 17:26:25--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/397/original/Sachin_ODI.csv
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 3.165.84.173, 3.165.84.114, 3.165.84.59, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|3.165.84.173|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26440 (26K) [text/plain]
# Saving to: ‘Sachin_ODI.csv’
#
# Sachin_ODI.csv      100%[===================>]  25.82K  --.-KB/s    in 0.06s
#
# 2026-02-11 17:26:26 (443 KB/s) - ‘Sachin_ODI.csv’ saved [26440/26440]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sachin_data  = pd.read_csv("Sachin_ODI.csv")

sachin_data .head()
# Out:
#    runs  NotOut mins  bf  fours  sixes      sr  Inns           Opp    Ground  \
# 0    13       0   30  15      3      0   86.66     1   New Zealand    Napier
# 1    37       0   75  51      3      1   72.54     2  South Africa  Hamilton
# 2    47       0   65  40      7      0  117.50     2     Australia   Dunedin
# 3    48       0   37  30      9      1  160.00     2    Bangladesh   Sharjah
# 4     4       0   13   9      1      0   44.44     2      Pakistan   Sharjah
#
#          Date        Winner    Won  century
# 0  1995-02-16   New Zealand  False    False
# 1  1995-02-18  South Africa  False    False
# 2  1995-02-22         India   True    False
# 3  1995-04-05         India   True    False
# 4  1995-04-07      Pakistan  False    False

# %%
sachin_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   runs     360 non-null    int64
#  1   NotOut   360 non-null    int64
#  2   mins     360 non-null    object
#  3   bf       360 non-null    int64
#  4   fours    360 non-null    int64
#  5   sixes    360 non-null    int64
#  6   sr       360 non-null    float64
#  7   Inns     360 non-null    int64
#  8   Opp      360 non-null    object
#  9   Ground   360 non-null    object
#  10  Date     360 non-null    object
#  11  Winner   360 non-null    object
#  12  Won      360 non-null    bool
#  13  century  360 non-null    bool
# dtypes: bool(2), float64(1), int64(6), object(5)
# memory usage: 34.6+ KB
