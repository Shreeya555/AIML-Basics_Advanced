# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreeya555/AIML-Basics_Advanced/blob/main/Pandas_Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown 1i-tHRLBGkq_X2BHrJtiRNMLA4AZCCzZc
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1i-tHRLBGkq_X2BHrJtiRNMLA4AZCCzZc
# From (redirected): https://drive.google.com/uc?id=1i-tHRLBGkq_X2BHrJtiRNMLA4AZCCzZc&confirm=t&uuid=183b5bc4-6648-4f6d-a5ab-aa8efb5572f7
# To: /content/lec_4_df_zomato.csv
# 100% 486M/486M [00:05<00:00, 88.4MB/s]

# %%
import pandas as pd

# %%
df= pd.read_csv('lec_4_df_zomato.csv')

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table Ratings  Total_Votes  \
# 0          Yes        Yes   4.1/5          775
# 1          Yes         No   4.1/5          787
# ...

# %%
df.iloc[2]
# Out:
# url                https://www.zomato.com/SanchurroBangalore?cont...
# address            1112, Next to KIMS Medical College, 17th Cross...
# name                                                 San Churro Cafe
# online_order                                                     Yes
# book_table                                                        No
# Ratings                                                        3.8/5
# Total_Votes                                                      918
# phone                                                 +91 9663487993
# location                                                Banashankari
# rest_type                                        Cafe, Casual Dining
# dish_liked         Churros, Cannelloni, Minestrone Soup, Hot Choc...
# cuisines                                      Cafe, Mexican, Italian
# cost_for_two                                                   800.0
# reviews_list       [('Rated 3.0', "RATED\n  Ambience is not that ...
# ...

# %%
df.iloc[0:2, 0:2]
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23193 entries, 0 to 23192
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              23193 non-null  object
#  1   address          23193 non-null  object
#  2   name             23193 non-null  object
#  3   online_order     23193 non-null  object
#  4   book_table       23193 non-null  object
#  5   Ratings          23193 non-null  object
#  6   Total_Votes      23193 non-null  int64
#  7   phone            23193 non-null  object
#  8   location         23193 non-null  object
#  9   rest_type        23193 non-null  object
#  10  dish_liked       23193 non-null  object
#  11  cuisines         23193 non-null  object
#  12  cost_for_two     23193 non-null  float64
#  13  reviews_list     23193 non-null  object
#  14  menu_item        23193 non-null  object
#  15  listed_in(type)  23193 non-null  object
# ...

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table Ratings  Total_Votes  \
# 0          Yes        Yes   4.1/5          775
# 1          Yes         No   4.1/5          787
# ...

# %%
df['flag']=1

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table Ratings  Total_Votes  \
# 0          Yes        Yes   4.1/5          775
# 1          Yes         No   4.1/5          787
# ...

# %%
df_explicit= df.set_index("name")

# %%
df_explicit
# Out:
#                                                                                                   url  \
# name
# Jalsa                                               https://www.zomato.com/bangalore/jalsa-banasha...
# Spice Elephant                                      https://www.zomato.com/bangalore/spice-elephan...
# San Churro Cafe                                     https://www.zomato.com/SanchurroBangalore?cont...
# Addhuri Udupi Bhojana                               https://www.zomato.com/bangalore/addhuri-udupi...
# Grand Village                                       https://www.zomato.com/bangalore/grand-village...
# ...                                                                                               ...
# Izakaya Gastro Pub                                  https://www.zomato.com/bangalore/izakaya-gastr...
# M Bar - Bengaluru Marriott Hotel Whitefield         https://www.zomato.com/bangalore/m-bar-bengalu...
# ...

# %%
df_explicit.loc["Jalsa"]
# Out:
#                                                      url  \
# name
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-maratha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-maratha...
#
#                                                  address online_order  \
# name
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# ...

# %%
df_explicit.loc["Jalsa", "flag"]=0

# %%
df_explicit.head()
# Out:
#                                                                      url  \
# name
# Jalsa                  https://www.zomato.com/bangalore/jalsa-banasha...
# Spice Elephant         https://www.zomato.com/bangalore/spice-elephan...
# San Churro Cafe        https://www.zomato.com/SanchurroBangalore?cont...
# Addhuri Udupi Bhojana  https://www.zomato.com/bangalore/addhuri-udupi...
# Grand Village          https://www.zomato.com/bangalore/grand-village...
#
#                                                                  address  \
# name
# Jalsa                  942, 21st Main Road, 2nd Stage, Banashankari, ...
# Spice Elephant         2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# San Churro Cafe        1112, Next to KIMS Medical College, 17th Cross...
# Addhuri Udupi Bhojana  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# Grand Village          10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
#
#                       online_order book_table Ratings  Total_Votes  \
# ...

# %%
df.loc["xyz"] #i dont know which column to search in for
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3355792258.py in <cell line: 0>()
# ----> 1 df.loc["only_rating"]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1429         # fall thru to straight lookup
#    1430         self._validate_key(key, axis)
# -> 1431         return self._get_label(key, axis=axis)
#    1432
#    1433     def _get_slice_axis(self, slice_obj: slice, axis: AxisInt):
#
# ...

# %%
df_explicit.loc["Jalsa"] #this search will happen in the name column
# Out:
#                                                      url  \
# name
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-maratha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-maratha...
#
#                                                  address online_order  \
# name
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# ...

# %%
#i want to search inside "only_rating" column
df[df["only_rating"] < 4]
# Out:
#                                                      url  \
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# 5      https://www.zomato.com/bangalore/timepass-dinn...
# 13     https://www.zomato.com/SanchurroBangalore?cont...
# ...                                                  ...
# 23186  https://www.zomato.com/bangalore/olivers-pub-d...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
#
#                                                  address  \
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...

# %%
df.loc[df["only_rating"] < 4, "flag"] = 123

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table Ratings  Total_Votes  \
# 0          Yes        Yes   4.1/5          775
# 1          Yes         No   4.1/5          787
# ...

# %%
#situations

data = {
    "Restaurant": ["R1", "R2", "R3", "R2", "R4", "R1"],
    "Votes": [120, 240, 150, 240, 80, 120],
    "Rating": [4.1, 4.5, 3.9, 4.5, 4.0, 4.1]
}

sample_df = pd.DataFrame(data)
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R2    240     4.5
# 4         R4     80     4.0
# 5         R1    120     4.1

# %%
sample_df.duplicated() #by default it keeps the first
                        #and treats other occurances as duplicates
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sample_df.duplicated(keep="last")
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
sample_df.duplicated(keep=False)
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sample_df[["Restaurant", "Votes"]]
# Out:
#   Restaurant  Votes
# 0         R1    120
# 1         R2    240
# 2         R3    150
# 3         R2    240
# 4         R4     80
# 5         R1    120

# %%
sample_df.drop_duplicates(keep='first')
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 4         R4     80     4.0

# %%
sample_df.drop_duplicates(keep='last')
# Out:
#   Restaurant  Votes  Rating
# 2         R3    150     3.9
# 3         R2    240     4.5
# 4         R4     80     4.0
# 5         R1    120     4.1

# %%
sample_df.drop_duplicates(keep='first', inplace=True)

# %%
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 4         R4     80     4.0

# %%
sample_df["Votes"].sum()
# Out:
# np.int64(590)

# %%
sample_df["Votes"].count()
# Out:
# np.int64(4)

# %%
sample_df["Votes"].mean()
# Out:
# np.float64(147.5)

# %%
sample_df[["Votes", "Rating"]].mean()
# Out:
# Votes     147.500
# Rating      4.125
# dtype: float64

# %%
sample_df[["Votes", "Rating"]].describe()
# Out:
#             Votes    Rating
# count    4.000000  4.000000
# mean   147.500000  4.125000
# std     68.007353  0.262996
# min     80.000000  3.900000
# 25%    110.000000  3.975000
# 50%    135.000000  4.050000
# 75%    172.500000  4.200000
# max    240.000000  4.500000

# %%
#interview question

sample_df[["Votes", "Rating"]].agg(["sum","mean","min"])
# Out:
#       Votes  Rating
# sum   590.0  16.500
# mean  147.5   4.125
# min    80.0   3.900

# %%
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 4         R4     80     4.0

# %%
sample_df.sort_values(by="Votes")
# Out:
#   Restaurant  Votes  Rating
# 4         R4     80     4.0
# 0         R1    120     4.1
# 2         R3    150     3.9
# 1         R2    240     4.5

# %%
sample_df.sort_values(by="Votes", ascending=False)
# Out:
#   Restaurant  Votes  Rating
# 1         R2    240     4.5
# 2         R3    150     3.9
# 0         R1    120     4.1
# 4         R4     80     4.0

# %%
#situations

data = {
    "Restaurant": ["R1", "R2", "R3", "R2", "R4", "R1","R5"],
    "Votes": [120, 240, 150, 240, 80, 120,120],
    "Rating": [4.1, 4.5, 3.9, 4.5, 4.0, 4.1,4.3]
}

sample_df = pd.DataFrame(data)
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R2    240     4.5
# 4         R4     80     4.0
# 5         R1    120     4.1
# 6         R5    120     4.3

# %%
sample_df.sort_values(by="Votes", ascending=False)
# Out:
#   Restaurant  Votes  Rating
# 1         R2    240     4.5
# 3         R2    240     4.5
# 2         R3    150     3.9
# 0         R1    120     4.1
# 5         R1    120     4.1
# 6         R5    120     4.3
# 4         R4     80     4.0

# %%
#IF THE VOTES ARE SAME DO SORTING ON THE BASIS OF DESC ORDER ORDER OF RATING

sample_df.sort_values(by=["Votes","Rating"], ascending=[False,False])
# Out:
#   Restaurant  Votes  Rating
# 1         R2    240     4.5
# 3         R2    240     4.5
# 2         R3    150     3.9
# 6         R5    120     4.3
# 0         R1    120     4.1
# 5         R1    120     4.1
# 4         R4     80     4.0

# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/214/original/amazon_data4.zip
# Out:
# --2026-02-04 17:12:19--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/101/214/original/amazon_data4.zip
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 18.164.173.58, 18.164.173.110, 18.164.173.18, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|18.164.173.58|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1943535 (1.9M) [application/zip]
# Saving to: ‘amazon_data4.zip’
#
# amazon_data4.zip    100%[===================>]   1.85M  1.40MB/s    in 1.3s
#
# 2026-02-04 17:12:21 (1.40 MB/s) - ‘amazon_data4.zip’ saved [1943535/1943535]

# %%
# !unzip amazon_data4.zip
# Out:
# Archive:  amazon_data4.zip
#   inflating: products.csv
#   inflating: orders.csv

# %%
#First load these two datasets

df_products= pd.read_csv("products.csv")

# %%
df_products.shape
# Out:
# (1465, 10)

# %%
df_orders= pd.read_csv("orders.csv")

# %%
df_orders.shape
# Out:
# (1465, 7)

# %%
df_products.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                 category discounted_price actual_price  rating  rating_count  \
# 0  Computers&Accessories             ₹399       ₹1,099     4.2       24269.0
# 1  Computers&Accessories             ₹199         ₹349     4.0       43994.0
# 2  Computers&Accessories             ₹199       ₹1,899     3.9        7928.0
# 3  Computers&Accessories             ₹329         ₹699     4.2       94363.0
# 4  Computers&Accessories             ₹154         ₹399     4.2       16905.0
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# ...

# %%
df_orders.head()
# Out:
#    product_id                                            user_id  \
# 0  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  B096MSW6CT  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  B08HDJ86NZ  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  B08CF3B7N1  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# ...

# %%
# Sample DataFrames
samples_orders = pd.DataFrame({
    'product_id': ['P001', 'P002', 'P003','P003'],
    'user_id': ['U001', 'U002', 'U003', 'U004'],
    'review_id': ['R001', 'R002', 'R003', 'R004']
})

samples_products = pd.DataFrame({
    'product_id': ['P001', 'P002', 'P004'],
    'product_name': ['Product A', 'Product B', 'Product D'],
    'category': ['Category 1', 'Category 2', 'Category 3']
})

# %%
samples_orders
# Out:
#   product_id user_id review_id
# 0       P001    U001      R001
# 1       P002    U002      R002
# 2       P003    U003      R003
# 3       P003    U004      R004

# %%
samples_products
# Out:
#   product_id product_name    category
# 0       P001    Product A  Category 1
# 1       P002    Product B  Category 2
# 2       P004    Product D  Category 3

# %%
samples_orders.merge(samples_products, on="product_id", how="inner")
# Out:
#   product_id user_id review_id product_name    category
# 0       P001    U001      R001    Product A  Category 1
# 1       P002    U002      R002    Product B  Category 2

# %%
samples_orders.merge(samples_products, on="product_id", how="left")
# Out:
#   product_id user_id review_id product_name    category
# 0       P001    U001      R001    Product A  Category 1
# 1       P002    U002      R002    Product B  Category 2
# 2       P003    U003      R003          NaN         NaN
# 3       P003    U004      R004          NaN         NaN

# %%
samples_orders.merge(samples_products, on="product_id", how="outer") #full join
# Out:
#   product_id user_id review_id product_name    category
# 0       P001    U001      R001    Product A  Category 1
# 1       P002    U002      R002    Product B  Category 2
# 2       P003    U003      R003          NaN         NaN
# 3       P003    U004      R004          NaN         NaN
# 4       P004     NaN       NaN    Product D  Category 3

# %%
#another way
final_table= pd.merge(samples_orders, samples_products, on="product_id", how="outer")
# Out:
#   product_id user_id review_id product_name    category
# 0       P001    U001      R001    Product A  Category 1
# 1       P002    U002      R002    Product B  Category 2
# 2       P003    U003      R003          NaN         NaN
# 3       P003    U004      R004          NaN         NaN
# 4       P004     NaN       NaN    Product D  Category 3
